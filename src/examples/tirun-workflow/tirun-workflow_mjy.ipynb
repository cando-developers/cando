# %% [markdown]
# # CANDO
# ## Computer Aided Nanomaterial Design and Optimization
# <ins>[CANDO](https://github.com/cando-developers/cando)</ins>  |  <ins>[Amber](https://ambermd.org/)</ins>  |  <ins>[ThirdLaw Technologies](https://www.thirdlaw.tech/)</ins>
#
# #### Thermodynamic Integration (TI) Demo <br>
#  - #### This JupyterLab notebook has been design to aid with the setup of relative free energy of binding calculations using TI.
#  - #### Molecule similarities are computed using a graph theory approach based on LOMAP (J Comput Aided Mol Des 27, 755–770 (2013). https://doi.org/10.1007/s10822-013-9678-y)
#  - #### Equilibration and dynamics simulations are carried out in Amber 20 using optimized parameters for GPU calculations.
#
# <hr style="border:1px solid black"> </hr>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Step 1:</b> <font color='black'>Setup the JupyterLab environment:</font></div>

# %%
(quickload :tirun-jupyter)
(use-package :tirun-jupyter)
(new-tirun)
# Out:
# To load "tirun-jupyter":
#   Load 1 ASDF system:
#     tirun-jupyter
#
# ; Loading "tirun-jupyter"
# [package lomap]...................................
# [package tirun-jupyter].....
# (:TIRUN-JUPYTER)
# T
# #<tirun-calculation>
# Jobs will be saved to /Users/meister/jobs/
# setenv CANDO_JOBS_DIRECTORY if you want it to go elsewhere

# %% [markdown]
# ***
# <div class="alert alert-block alert-info">
#     <b>Step 2:</b> <font color='black'>Load a receptor as a PDB file::</font></div>

# %%
(load-receptor)
# Out:
# A Jupyter Widget
# A Jupyter Widget

# %% [markdown]
# ***
# <div class="alert alert-block alert-info">
#     <b>Step 3:</b> <font color='black'>Load a set of ligands as an SDF file:</font></div>

# %%
(load-ligands)
# Out:
# A Jupyter Widget

# %% [markdown]
# ***
# <div class="alert alert-block alert-info">
#     <b>Step 4:</b> <font color='black'>Select a subset of the ligands if you choose:</font></div>

# %%
(select-ligands)
# Out:
# A Jupyter Widget

# %% [markdown]
# ***
# <div class="alert alert-block alert-info">
# <b>Step 5:</b> <font color='black'>Calculate the optimized map of relative binding free energy calculations:</font><br>
#  - Each node corresponds to a single molecule from the set.<br>
#  - Each edge corresponds to the similarity between the two molecules and the RBFE calculation to be conducted.
# </div>

# %%
(lomap)
# Out:
# A Jupyter Widget

# %% [markdown]
# ***
# <div class="alert alert-block alert-info">
# <b>Step 6:</b> <font color='black'>Configure the calculations</font></div>

# %%
(configure-jobs)
# Out:
# A Jupyter Widget

# %% [markdown]
# ***
# <div class="alert alert-block alert-info">
# <b>Step 7:</b> <font color='black'>Write out the directories and files needed for all calculations:</font></div>

# %%
(write-jobs)
# Out:
# A Jupyter Widget

# %% [markdown]
# ***
# <div class="alert alert-block alert-info">
# <b>Step 8:</b> <font color='black'>Submit the calculation to the distributor:</font></div>

# %%
(submit-calc)
# Out:
# A Jupyter Widget

# %%
(print "Are we live?")
# Out:
# "Are we live?"
# "Are we live?"

# %% [markdown]
# ***
# <div class="alert alert-block alert-info">
# <b>Step 9:</b> <font color='black'>Check the status of the jobs:</font></div>

# %%
(check-calc)
# Out:
# A Jupyter Widget

# %% [markdown]
# ## Key Features:
#  - #### Easily identify problems with your receptor PDB files and make corrections right in the notebook.
#  - #### 2-D chemical structures of your ligands are displayed alongside 3-D renderings.
#  - #### Extremely fast automated or user-defined planning of free energy calculations for hit-lead optimization.
#  - #### Full control of MD simulation parameters.
#  - #### 1-click job execution.
#  - #### Real-time calculation monitoring. (coming soon)

# %% [markdown]
# ***
# <div class="alert alert-block alert-info">
# <b>Utilities:</b> <font color='black'>Start a debugging server</font></div>

# %%
(start-swank 4006)
# Out:
# Checking SLIME_HOME
# ; Compiling file parallel: /Users/meister/Dropbox/emacs.d/slime/contrib/swank-util.lisp
# Time real(0.288 secs) run(0.288 secs) consed(17350640 bytes) unwinds(284)
# ; Compiling file parallel: /Users/meister/Dropbox/emacs.d/slime/contrib/swank-repl.lisp
# Time real(0.864 secs) run(0.864 secs) consed(32661264 bytes) unwinds(1135)
# ; Compiling file parallel: /Users/meister/Dropbox/emacs.d/slime/contrib/swank-c-p-c.lisp
# Time real(0.535 secs) run(0.535 secs) consed(23760376 bytes) unwinds(902)
# ; Compiling file parallel: /Users/meister/Dropbox/emacs.d/slime/contrib/swank-arglists.lisp
# Time real(7.665 secs) run(7.665 secs) consed(395720736 bytes) interps(4) unwinds(6142)
# ; Compiling file parallel: /Users/meister/Dropbox/emacs.d/slime/contrib/swank-fuzzy.lisp
# Time real(1.770 secs) run(1.770 secs) consed(75280984 bytes) unwinds(2100)
# ; Compiling file parallel: /Users/meister/Dropbox/emacs.d/slime/contrib/swank-fancy-inspector.lisp
# Time real(3.037 secs) run(3.036 secs) consed(159508568 bytes) interps(7) unwinds(3540)
# ; Compiling file parallel: /Users/meister/Dropbox/emacs.d/slime/contrib/swank-presentations.lisp
# Time real(0.804 secs) run(0.804 secs) consed(22766488 bytes) unwinds(789)
# ; Compiling file parallel: /Users/meister/Dropbox/emacs.d/slime/contrib/swank-presentation-streams.lisp
# Time real(0.909 secs) run(0.909 secs) consed(33934416 bytes) unwinds(961)
# ; Compiling file parallel: /Users/meister/Dropbox/emacs.d/slime/contrib/swank-asdf.lisp
# Time real(7.787 secs) run(7.787 secs) consed(86804376 bytes) interps(4) unwinds(1899)
# ; Compiling file parallel: /Users/meister/Dropbox/emacs.d/slime/contrib/swank-package-fu.lisp
# Time real(0.102 secs) run(0.102 secs) consed(3432192 bytes) unwinds(276)
# ; Compiling file parallel: /Users/meister/Dropbox/emacs.d/slime/contrib/swank-hyperdoc.lisp
# Time real(0.364 secs) run(0.363 secs) consed(1726320 bytes) unwinds(65)
# ; Compiling file parallel: /Users/meister/Dropbox/emacs.d/slime/contrib/swank-mrepl.lisp
# Time real(0.433 secs) run(0.433 secs) consed(19269784 bytes) unwinds(665)
# ; Compiling file parallel: /Users/meister/Dropbox/emacs.d/slime/contrib/swank-trace-dialog.lisp
# Time real(2.185 secs) run(2.185 secs) consed(27061632 bytes) unwinds(849)
# ; Compiling file parallel: /Users/meister/Dropbox/emacs.d/slime/contrib/swank-macrostep.lisp
# Time real(0.654 secs) run(0.654 secs) consed(32182624 bytes) unwinds(772)
# ; Compiling file parallel: /Users/meister/Dropbox/emacs.d/slime/contrib/swank-quicklisp.lisp
# T
# Time real(0.350 secs) run(0.350 secs) consed(1337168 bytes) unwinds(35)
# About to start swank server
# Started swank server
# Undefined variable *COMMUNICATION-STYLE*
#    [Condition of type COMPILER:UNDEFINED-VARIABLE-WARNING]
#
# #<DISSECT:ENVIRONMENT>
#    [Environment of thread #<PROCESS TOP-LEVEL @0x116ec3f09 (Running)>]
#
#
# Backtrace:
#  4: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT-VARIABLE (T T T))> #<ATOM-CST raw: SWANK:*COMMUNICATION-STYLE* @0x143e37f99> #<INLINE ERROR NOTINLINE @0x137d47e49> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  8: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (T T T))> #<ATOM-CST raw: SWANK:*COMMUNICATION-STYLE* @0x143e37f99> #<INLINE ERROR NOTINLINE @0x137d47e49> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  10: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  11: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (:AROUND) (T T T))> #<FUNCTION REPL> #<ATOM-CST raw: SWANK:*COMMUNICATION-STYLE* @0x143e37f99> #<INLINE ERROR NOTINLINE @0x137d47e49> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  13: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<ATOM-CST raw: SWANK:*COMMUNICATION-STYLE* @0x143e37f99> #<INLINE ERROR NOTINLINE @0x137d47e49> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  17: (#<FUNCTION CLEAVIR-CST-TO-AST::CONVERT-SEQUENCE> #<CONS-CST raw: ("~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) @0x143e37f39> #<INLINE ERROR NOTINLINE @0x137d47e49> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  18: (#<FUNCTION CLEAVIR-CST-TO-AST::MAKE-CALL> #<CONS-CST raw: (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) @0x143e37e79> #<CLEAVIR-ENVIRONMENT:GLOBAL-FUNCTION-INFO> #<INLINE ERROR NOTINLINE @0x137d47e49> #<CONS-CST raw: ("~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) @0x143e37f39> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  19: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST::CONVERT-CST (T CLEAVIR-ENVIRONMENT:GLOBAL-FUNCTION-INFO T T))> #<CONS-CST raw: (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) @0x143e37e79> #<CLEAVIR-ENVIRONMENT:GLOBAL-FUNCTION-INFO> #<INLINE ERROR NOTINLINE @0x137d47e49> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  23: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (T T T))> #<CONS-CST raw: (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) @0x143e37e79> #<INLINE ERROR NOTINLINE @0x137d47e49> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  25: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  26: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (:AROUND) (T T T))> #<FUNCTION REPL> #<CONS-CST raw: (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) @0x143e37e79> #<INLINE ERROR NOTINLINE @0x137d47e49> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  28: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<CONS-CST raw: (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) @0x143e37e79> #<INLINE ERROR NOTINLINE @0x137d47e49> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  32: (#<FUNCTION CLEAVIR-CST-TO-AST::CONVERT-SEQUENCE> #<CONS-CST raw: ((ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) (CLEAVIR-PRIMOP:UNREACHABLE)) @0x137d36069> #<INLINE ERROR NOTINLINE @0x137d47e49> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  33: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT-SPECIAL ((EQL #:|'LOCALLY|) T T T))> LOCALLY #<CONS-CST raw: (LOCALLY (DECLARE (NOTINLINE ERROR)) (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) (CLEAVIR-PRIMOP:UNREACHABLE)) @0x137d36219> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  35: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  39: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST::CONVERT-CST (T CLEAVIR-ENVIRONMENT:SPECIAL-OPERATOR-INFO T T))> #<CONS-CST raw: (LOCALLY (DECLARE (NOTINLINE ERROR)) (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) (CLEAVIR-PRIMOP:UNREACHABLE)) @0x137d36219> #<CLEAVIR-ENVIRONMENT:SPECIAL-OPERATOR-INFO> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  43: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (T T T))> #<CONS-CST raw: (LOCALLY (DECLARE (NOTINLINE ERROR)) (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) (CLEAVIR-PRIMOP:UNREACHABLE)) @0x137d36219> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  45: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  46: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (:AROUND) (T T T))> #<FUNCTION REPL> #<CONS-CST raw: (LOCALLY (DECLARE (NOTINLINE ERROR)) (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) (CLEAVIR-PRIMOP:UNREACHABLE)) @0x137d36219> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  48: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<CONS-CST raw: (LOCALLY (DECLARE (NOTINLINE ERROR)) (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) (CLEAVIR-PRIMOP:UNREACHABLE)) @0x137d36219> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  52: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST::CONVERT-CST (T CLEAVIR-ENVIRONMENT:GLOBAL-FUNCTION-INFO T T))> #<CONS-CST raw: (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) @0x143e37e79> #<CLEAVIR-ENVIRONMENT:GLOBAL-FUNCTION-INFO> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  56: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (T T T))> #<CONS-CST raw: (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) @0x143e37e79> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  58: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  59: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (:AROUND) (T T T))> #<FUNCTION REPL> #<CONS-CST raw: (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) @0x143e37e79> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  61: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<CONS-CST raw: (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*) @0x143e37e79> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  65: (#<FUNCTION CLEAVIR-CST-TO-AST::CONVERT-SEQUENCE> #<CONS-CST raw: ((ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x137d36ba9> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  66: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT-SPECIAL ((EQL #:|'PROGN|) T T T))> PROGN #<CONS-CST raw: (PROGN (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x137d36459> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  68: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  72: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST::CONVERT-CST (T CLEAVIR-ENVIRONMENT:SPECIAL-OPERATOR-INFO T T))> #<CONS-CST raw: (PROGN (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x137d36459> #<CLEAVIR-ENVIRONMENT:SPECIAL-OPERATOR-INFO> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  76: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (T T T))> #<CONS-CST raw: (PROGN (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x137d36459> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  78: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  79: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (:AROUND) (T T T))> #<FUNCTION REPL> #<CONS-CST raw: (PROGN (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x137d36459> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  81: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<CONS-CST raw: (PROGN (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x137d36459> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  85: (#<FUNCTION CLEAVIR-CST-TO-AST::CONVERT-BODY> #<CLEAVIR-CST-TO-AST::BODY> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  86: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETER-GROUPS (NULL T T T T T))> NIL NIL NIL #<CLEAVIR-CST-TO-AST::BODY> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  92: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETERS-IN-GROUP (NULL T T T T T T T T))> NIL NIL NIL NIL NIL NIL #<CLEAVIR-CST-TO-AST::BODY> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  98: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETER-GROUP (CONCRETE-SYNTAX-TREE:MULTI-PARAMETER-GROUP-MIXIN T T T T T T T T))> #<ORDINARY-REQUIRED-PARAMETER-GROUP parameters: NIL @0x137d368d9> NIL NIL NIL NIL NIL #<CLEAVIR-CST-TO-AST::BODY> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  104: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETER-GROUPS (CONS T T T T T))> (#<ORDINARY-REQUIRED-PARAMETER-GROUP parameters: NIL @0x137d368d9>) (NIL) (NIL) #<CLEAVIR-CST-TO-AST::BODY> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  110: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT-CODE (T T T T))> #<ATOM-CST raw: NIL @0x143c99219> #<CONS-CST raw: ((ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x137d36ba9> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT> ORIGIN (#<SOURCE-POS-INFO :fileId 790 :filepos 50283 :lineno 1392 :column 3> . #<SOURCE-POS-INFO :fileId 790 :filepos 50467 :lineno 1394 :column 86>))
#  112: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT-CODE (T T T CLASP-CLEAVIR:CLASP))> #<FUNCTION (METHOD CONVERT-CODE (T T T T))> #<ATOM-CST raw: NIL @0x143c99219> #<CONS-CST raw: ((ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x137d36ba9> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT> ORIGIN (#<SOURCE-POS-INFO :fileId 790 :filepos 50283 :lineno 1392 :column 3> . #<SOURCE-POS-INFO :fileId 790 :filepos 50467 :lineno 1394 :column 86>))
#  114: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<ATOM-CST raw: NIL @0x143c99219> #<CONS-CST raw: ((ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x137d36ba9> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT> ORIGIN (#<SOURCE-POS-INFO :fileId 790 :filepos 50283 :lineno 1392 :column 3> . #<SOURCE-POS-INFO :fileId 790 :filepos 50467 :lineno 1394 :column 86>))
#  120: (#<FUNCTION CLEAVIR-CST-TO-AST::CONVERT-LAMBDA-FUNCTION> #<CONS-CST raw: (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x137d36c09> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  121: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT-SPECIAL ((EQL #:|'FUNCTION|) T T T))> FUNCTION #<CONS-CST raw: #'(LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x137d36d29> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  123: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  127: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST::CONVERT-CST (T CLEAVIR-ENVIRONMENT:SPECIAL-OPERATOR-INFO T T))> #<CONS-CST raw: #'(LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x137d36d29> #<CLEAVIR-ENVIRONMENT:SPECIAL-OPERATOR-INFO> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  131: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (T T T))> #<CONS-CST raw: #'(LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x137d36d29> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  133: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  134: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (:AROUND) (T T T))> #<FUNCTION REPL> #<CONS-CST raw: #'(LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x137d36d29> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  136: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<CONS-CST raw: #'(LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x137d36d29> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  140: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST::CONVERT-CST (T CLEAVIR-ENVIRONMENT:GLOBAL-MACRO-INFO T T))> #<CONS-CST raw: (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x143e37db9> #<CLEAVIR-ENVIRONMENT:GLOBAL-MACRO-INFO> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  144: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (T T T))> #<CONS-CST raw: (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x143e37db9> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  146: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  147: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (:AROUND) (T T T))> #<FUNCTION REPL> #<CONS-CST raw: (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x143e37db9> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  149: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<CONS-CST raw: (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)) @0x143e37db9> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  153: (#<FUNCTION CLEAVIR-CST-TO-AST::CONVERT-SEQUENCE> #<CONS-CST raw: (NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))) @0x143e37d59> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  154: (#<FUNCTION CLEAVIR-CST-TO-AST::MAKE-CALL> #<CONS-CST raw: (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))) @0x143e37cf9> #<CLEAVIR-ENVIRONMENT:GLOBAL-FUNCTION-INFO> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CONS-CST raw: (NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))) @0x143e37d59> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  155: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST::CONVERT-CST (T CLEAVIR-ENVIRONMENT:GLOBAL-FUNCTION-INFO T T))> #<CONS-CST raw: (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))) @0x143e37cf9> #<CLEAVIR-ENVIRONMENT:GLOBAL-FUNCTION-INFO> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  159: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (T T T))> #<CONS-CST raw: (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))) @0x143e37cf9> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  161: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  162: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (:AROUND) (T T T))> #<FUNCTION REPL> #<CONS-CST raw: (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))) @0x143e37cf9> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  164: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<CONS-CST raw: (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))) @0x143e37cf9> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  168: (#<FUNCTION CLEAVIR-CST-TO-AST::CONVERT-SEQUENCE> #<CONS-CST raw: ((CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x137ce3d29> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  169: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT-SPECIAL ((EQL #:|'PROGN|) T T T))> PROGN #<CONS-CST raw: (PROGN (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x137d2d7b9> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  171: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  175: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST::CONVERT-CST (T CLEAVIR-ENVIRONMENT:SPECIAL-OPERATOR-INFO T T))> #<CONS-CST raw: (PROGN (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x137d2d7b9> #<CLEAVIR-ENVIRONMENT:SPECIAL-OPERATOR-INFO> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  179: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (T T T))> #<CONS-CST raw: (PROGN (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x137d2d7b9> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  181: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  182: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (:AROUND) (T T T))> #<FUNCTION REPL> #<CONS-CST raw: (PROGN (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x137d2d7b9> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  184: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<CONS-CST raw: (PROGN (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x137d2d7b9> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  188: (#<FUNCTION CLEAVIR-CST-TO-AST::CONVERT-BODY> #<CLEAVIR-CST-TO-AST::BODY> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  189: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETER-GROUPS (NULL T T T T T))> NIL NIL NIL #<CLEAVIR-CST-TO-AST::BODY> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  195: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETERS-IN-GROUP (NULL T T T T T T T T))> NIL NIL NIL NIL NIL NIL #<CLEAVIR-CST-TO-AST::BODY> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  201: (#<FUNCTION (LAMBDA NIL)>)
#  202: (#<FUNCTION CLEAVIR-CST-TO-AST::SET-OR-BIND-VARIABLE> #<ATOM-CST raw: TIMEOUT @0x143c99699> #<CLEAVIR-AST:LEXICAL-AST> #<FUNCTION (LAMBDA NIL)> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  203: (#<FUNCTION CLEAVIR-CST-TO-AST::PROCESS-INIT-PARAMETER> #<ATOM-CST raw: TIMEOUT @0x143c99699> #<CLEAVIR-AST:LEXICAL-AST> NIL #<CLEAVIR-AST:LEXICAL-AST> #<CLEAVIR-AST:LOAD-TIME-VALUE-AST> #<VARIABLE-IGNORE TIMEOUT IGNORE @0x137d2d4b9> #<FUNCTION (LAMBDA NIL)> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  204: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETER (CONCRETE-SYNTAX-TREE:ORDINARY-OPTIONAL-PARAMETER T T T T T T T T T T T))> #<CONCRETE-SYNTAX-TREE:ORDINARY-OPTIONAL-PARAMETER> NIL NIL ((#<CONS-CST raw: (IGNORE TIMEOUT) @0x137d2d8a9>)) NIL NIL (#<CLEAVIR-AST:LEXICAL-AST> #<CLEAVIR-AST:LEXICAL-AST>) NIL NIL #<CLEAVIR-CST-TO-AST::BODY> #<VARIABLE-IGNORE STREAMS IGNORE @0x137d2d6c9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  210: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETERS-IN-GROUP (CONS T T T T T T T T))> (#<CONCRETE-SYNTAX-TREE:ORDINARY-OPTIONAL-PARAMETER>) NIL (((#<CONS-CST raw: (IGNORE TIMEOUT) @0x137d2d8a9>))) NIL ((#<CLEAVIR-AST:LEXICAL-AST> #<CLEAVIR-AST:LEXICAL-AST>)) NIL #<CLEAVIR-CST-TO-AST::BODY> #<VARIABLE-IGNORE STREAMS IGNORE @0x137d2d6c9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  216: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETER-GROUP (CONCRETE-SYNTAX-TREE:MULTI-PARAMETER-GROUP-MIXIN T T T T T T T T))> #<ORDINARY-OPTIONAL-PARAMETER-GROUP parameters: (#<CONCRETE-SYNTAX-TREE:ORDINARY-OPTIONAL-PARAMETER>) @0x137d2dd89> NIL (((#<CONS-CST raw: (IGNORE TIMEOUT) @0x137d2d8a9>))) NIL ((#<CLEAVIR-AST:LEXICAL-AST> #<CLEAVIR-AST:LEXICAL-AST>)) NIL #<CLEAVIR-CST-TO-AST::BODY> #<VARIABLE-IGNORE STREAMS IGNORE @0x137d2d6c9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  222: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETER-GROUPS (CONS T T T T T))> (#<ORDINARY-OPTIONAL-PARAMETER-GROUP parameters: (#<CONCRETE-SYNTAX-TREE:ORDINARY-OPTIONAL-PARAMETER>) @0x137d2dd89>) ((((#<CONS-CST raw: (IGNORE TIMEOUT) @0x137d2d8a9>)))) (((#<CLEAVIR-AST:LEXICAL-AST> #<CLEAVIR-AST:LEXICAL-AST>))) #<CLEAVIR-CST-TO-AST::BODY> #<VARIABLE-IGNORE STREAMS IGNORE @0x137d2d6c9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  228: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETERS-IN-GROUP (NULL T T T T T T T T))> NIL (#<ORDINARY-OPTIONAL-PARAMETER-GROUP parameters: (#<CONCRETE-SYNTAX-TREE:ORDINARY-OPTIONAL-PARAMETER>) @0x137d2dd89>) NIL ((((#<CONS-CST raw: (IGNORE TIMEOUT) @0x137d2d8a9>)))) NIL (((#<CLEAVIR-AST:LEXICAL-AST> #<CLEAVIR-AST:LEXICAL-AST>))) #<CLEAVIR-CST-TO-AST::BODY> #<VARIABLE-IGNORE STREAMS IGNORE @0x137d2d6c9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  234: (#<FUNCTION (LAMBDA NIL)>)
#  235: (#<FUNCTION CLEAVIR-CST-TO-AST::SET-OR-BIND-VARIABLE> #<ATOM-CST raw: STREAMS @0x143c996f9> #<CLEAVIR-AST:LEXICAL-AST> #<FUNCTION (LAMBDA NIL)> #<VARIABLE-IGNORE STREAMS IGNORE @0x137d2d6c9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  236: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETER (CONCRETE-SYNTAX-TREE:SIMPLE-VARIABLE T T T T T T T T T T T))> #<CONCRETE-SYNTAX-TREE:SIMPLE-VARIABLE> NIL (#<ORDINARY-OPTIONAL-PARAMETER-GROUP parameters: (#<CONCRETE-SYNTAX-TREE:ORDINARY-OPTIONAL-PARAMETER>) @0x137d2dd89>) ((#<CONS-CST raw: (IGNORE STREAMS) @0x137d2d969>)) NIL ((((#<CONS-CST raw: (IGNORE TIMEOUT) @0x137d2d8a9>)))) #<CLEAVIR-AST:LEXICAL-AST> NIL (((#<CLEAVIR-AST:LEXICAL-AST> #<CLEAVIR-AST:LEXICAL-AST>))) #<CLEAVIR-CST-TO-AST::BODY> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  242: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETERS-IN-GROUP (CONS T T T T T T T T))> (#<CONCRETE-SYNTAX-TREE:SIMPLE-VARIABLE>) (#<ORDINARY-OPTIONAL-PARAMETER-GROUP parameters: (#<CONCRETE-SYNTAX-TREE:ORDINARY-OPTIONAL-PARAMETER>) @0x137d2dd89>) (((#<CONS-CST raw: (IGNORE STREAMS) @0x137d2d969>))) ((((#<CONS-CST raw: (IGNORE TIMEOUT) @0x137d2d8a9>)))) (#<CLEAVIR-AST:LEXICAL-AST>) (((#<CLEAVIR-AST:LEXICAL-AST> #<CLEAVIR-AST:LEXICAL-AST>))) #<CLEAVIR-CST-TO-AST::BODY> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  248: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETER-GROUP (CONCRETE-SYNTAX-TREE:MULTI-PARAMETER-GROUP-MIXIN T T T T T T T T))> #<ORDINARY-REQUIRED-PARAMETER-GROUP parameters: (#<CONCRETE-SYNTAX-TREE:SIMPLE-VARIABLE>) @0x137ce32d9> (#<ORDINARY-OPTIONAL-PARAMETER-GROUP parameters: (#<CONCRETE-SYNTAX-TREE:ORDINARY-OPTIONAL-PARAMETER>) @0x137d2dd89>) (((#<CONS-CST raw: (IGNORE STREAMS) @0x137d2d969>))) ((((#<CONS-CST raw: (IGNORE TIMEOUT) @0x137d2d8a9>)))) (#<CLEAVIR-AST:LEXICAL-AST>) (((#<CLEAVIR-AST:LEXICAL-AST> #<CLEAVIR-AST:LEXICAL-AST>))) #<CLEAVIR-CST-TO-AST::BODY> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  254: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETER-GROUPS (CONS T T T T T))> (#<ORDINARY-REQUIRED-PARAMETER-GROUP parameters: (#<CONCRETE-SYNTAX-TREE:SIMPLE-VARIABLE>) @0x137ce32d9> #<ORDINARY-OPTIONAL-PARAMETER-GROUP parameters: (#<CONCRETE-SYNTAX-TREE:ORDINARY-OPTIONAL-PARAMETER>) @0x137d2dd89>) ((((#<CONS-CST raw: (IGNORE STREAMS) @0x137d2d969>))) (((#<CONS-CST raw: (IGNORE TIMEOUT) @0x137d2d8a9>)))) ((#<CLEAVIR-AST:LEXICAL-AST>) ((#<CLEAVIR-AST:LEXICAL-AST> #<CLEAVIR-AST:LEXICAL-AST>))) #<CLEAVIR-CST-TO-AST::BODY> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  260: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT-CODE (T T T T))> #<CONS-CST raw: (STREAMS &OPTIONAL TIMEOUT) @0x143c995a9> #<CONS-CST raw: ((DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x137ce3d59> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT> ORIGIN (#<SOURCE-POS-INFO :fileId 790 :filepos 49721 :lineno 1379 :column 0> . #<SOURCE-POS-INFO :fileId 790 :filepos 50469 :lineno 1394 :column 88>))
#  262: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT-CODE (T T T CLASP-CLEAVIR:CLASP))> #<FUNCTION (METHOD CONVERT-CODE (T T T T))> #<CONS-CST raw: (STREAMS &OPTIONAL TIMEOUT) @0x143c995a9> #<CONS-CST raw: ((DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x137ce3d59> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT> ORIGIN (#<SOURCE-POS-INFO :fileId 790 :filepos 49721 :lineno 1379 :column 0> . #<SOURCE-POS-INFO :fileId 790 :filepos 50469 :lineno 1394 :column 88>))
#  264: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<CONS-CST raw: (STREAMS &OPTIONAL TIMEOUT) @0x143c995a9> #<CONS-CST raw: ((DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x137ce3d59> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT> ORIGIN (#<SOURCE-POS-INFO :fileId 790 :filepos 49721 :lineno 1379 :column 0> . #<SOURCE-POS-INFO :fileId 790 :filepos 50469 :lineno 1394 :column 88>))
#  270: (#<FUNCTION CLEAVIR-CST-TO-AST::CONVERT-LAMBDA-FUNCTION> #<CONS-CST raw: (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x137ce3db9> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  271: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT-SPECIAL ((EQL #:|'FUNCTION|) T T T))> FUNCTION #<CONS-CST raw: #'(LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x137ce3e49> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  273: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  277: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST::CONVERT-CST (T CLEAVIR-ENVIRONMENT:SPECIAL-OPERATOR-INFO T T))> #<CONS-CST raw: #'(LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x137ce3e49> #<CLEAVIR-ENVIRONMENT:SPECIAL-OPERATOR-INFO> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  281: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (T T T))> #<CONS-CST raw: #'(LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x137ce3e49> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  283: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  284: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (:AROUND) (T T T))> #<FUNCTION REPL> #<CONS-CST raw: #'(LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x137ce3e49> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  286: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<CONS-CST raw: #'(LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x137ce3e49> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  290: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST::CONVERT-CST (T CLEAVIR-ENVIRONMENT:GLOBAL-MACRO-INFO T T))> #<CONS-CST raw: (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x143a159c9> #<CLEAVIR-ENVIRONMENT:GLOBAL-MACRO-INFO> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  294: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (T T T))> #<CONS-CST raw: (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x143a159c9> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  296: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  297: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (:AROUND) (T T T))> #<FUNCTION REPL> #<CONS-CST raw: (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x143a159c9> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  299: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<CONS-CST raw: (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*)))) @0x143a159c9> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  303: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT-SPECIAL ((EQL #:|'CLEAVIR-PRIMOP:MULTIPLE-VALUE-SETQ|) T T T))> MULTIPLE-VALUE-SETQ #<CONS-CST raw: (CLEAVIR-PRIMOP:MULTIPLE-VALUE-SETQ (#:STORE146502146503) (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))))) @0x137ccb849> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  305: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  309: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST::CONVERT-CST (T CLEAVIR-ENVIRONMENT:SPECIAL-OPERATOR-INFO T T))> #<CONS-CST raw: (CLEAVIR-PRIMOP:MULTIPLE-VALUE-SETQ (#:STORE146502146503) (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))))) @0x137ccb849> #<CLEAVIR-ENVIRONMENT:SPECIAL-OPERATOR-INFO> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  313: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (T T T))> #<CONS-CST raw: (CLEAVIR-PRIMOP:MULTIPLE-VALUE-SETQ (#:STORE146502146503) (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))))) @0x137ccb849> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  315: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  316: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (:AROUND) (T T T))> #<FUNCTION REPL> #<CONS-CST raw: (CLEAVIR-PRIMOP:MULTIPLE-VALUE-SETQ (#:STORE146502146503) (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))))) @0x137ccb849> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  318: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<CONS-CST raw: (CLEAVIR-PRIMOP:MULTIPLE-VALUE-SETQ (#:STORE146502146503) (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))))) @0x137ccb849> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  322: (#<FUNCTION CLEAVIR-CST-TO-AST::CONVERT-SEQUENCE> #<CONS-CST raw: ((CLEAVIR-PRIMOP:MULTIPLE-VALUE-SETQ (#:STORE146502146503) (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))))) (LET ((#:STORE146502 #:STORE146502146503)) (FUNCALL #'(SETF GET) #:STORE146502 #:TEMP146500 #:TEMP146501))) @0x137ccb879> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  323: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT-SPECIAL ((EQL #:|'PROGN|) T T T))> PROGN #<CONS-CST raw: (PROGN (CLEAVIR-PRIMOP:MULTIPLE-VALUE-SETQ (#:STORE146502146503) (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))))) (LET ((#:STORE146502 #:STORE146502146503)) (FUNCALL #'(SETF GET) #:STORE146502 #:TEMP146500 #:TEMP146501))) @0x137cd2279> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  325: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  329: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST::CONVERT-CST (T CLEAVIR-ENVIRONMENT:SPECIAL-OPERATOR-INFO T T))> #<CONS-CST raw: (PROGN (CLEAVIR-PRIMOP:MULTIPLE-VALUE-SETQ (#:STORE146502146503) (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))))) (LET ((#:STORE146502 #:STORE146502146503)) (FUNCALL #'(SETF GET) #:STORE146502 #:TEMP146500 #:TEMP146501))) @0x137cd2279> #<CLEAVIR-ENVIRONMENT:SPECIAL-OPERATOR-INFO> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  333: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (T T T))> #<CONS-CST raw: (PROGN (CLEAVIR-PRIMOP:MULTIPLE-VALUE-SETQ (#:STORE146502146503) (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))))) (LET ((#:STORE146502 #:STORE146502146503)) (FUNCALL #'(SETF GET) #:STORE146502 #:TEMP146500 #:TEMP146501))) @0x137cd2279> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  335: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  336: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (:AROUND) (T T T))> #<FUNCTION REPL> #<CONS-CST raw: (PROGN (CLEAVIR-PRIMOP:MULTIPLE-VALUE-SETQ (#:STORE146502146503) (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))))) (LET ((#:STORE146502 #:STORE146502146503)) (FUNCALL #'(SETF GET) #:STORE146502 #:TEMP146500 #:TEMP146501))) @0x137cd2279> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  338: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<CONS-CST raw: (PROGN (CLEAVIR-PRIMOP:MULTIPLE-VALUE-SETQ (#:STORE146502146503) (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))))) (LET ((#:STORE146502 #:STORE146502146503)) (FUNCALL #'(SETF GET) #:STORE146502 #:TEMP146500 #:TEMP146501))) @0x137cd2279> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  342: (#<FUNCTION CLEAVIR-CST-TO-AST::CONVERT-BODY> #<CLEAVIR-CST-TO-AST::BODY> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  343: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETER-GROUPS (NULL T T T T T))> NIL NIL NIL #<CLEAVIR-CST-TO-AST::BODY> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  349: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETERS-IN-GROUP (NULL T T T T T T T T))> NIL NIL NIL NIL NIL NIL #<CLEAVIR-CST-TO-AST::BODY> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  355: (#<FUNCTION (LAMBDA NIL)>)
#  356: (#<FUNCTION CLEAVIR-CST-TO-AST::SET-OR-BIND-VARIABLE> #<ATOM-CST raw: #:STORE146502146503 @0x137ccb8a9> #<CLEAVIR-AST:LEXICAL-AST> #<FUNCTION (LAMBDA NIL)> #<LEXICAL-VARIABLE #:STORE146502146503 #<CLEAVIR-AST:LEXICAL-AST> @0x137cd21e9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  357: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETER (CONCRETE-SYNTAX-TREE:SIMPLE-VARIABLE T T T T T T T T T T T))> #<CONCRETE-SYNTAX-TREE:SIMPLE-VARIABLE> NIL NIL (NIL) NIL NIL #<CLEAVIR-AST:LEXICAL-AST> NIL NIL #<CLEAVIR-CST-TO-AST::BODY> #<LEXICAL-VARIABLE #:TEMP146501 #<CLEAVIR-AST:LEXICAL-AST> @0x137ccbcf9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  363: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETERS-IN-GROUP (CONS T T T T T T T T))> (#<CONCRETE-SYNTAX-TREE:SIMPLE-VARIABLE>) NIL ((NIL)) NIL (#<CLEAVIR-AST:LEXICAL-AST>) NIL #<CLEAVIR-CST-TO-AST::BODY> #<LEXICAL-VARIABLE #:TEMP146501 #<CLEAVIR-AST:LEXICAL-AST> @0x137ccbcf9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  369: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETER-GROUP (CONCRETE-SYNTAX-TREE:MULTI-PARAMETER-GROUP-MIXIN T T T T T T T T))> #<ORDINARY-REQUIRED-PARAMETER-GROUP parameters: (#<CONCRETE-SYNTAX-TREE:SIMPLE-VARIABLE>) @0x137cd2879> NIL ((NIL)) NIL (#<CLEAVIR-AST:LEXICAL-AST>) NIL #<CLEAVIR-CST-TO-AST::BODY> #<LEXICAL-VARIABLE #:TEMP146501 #<CLEAVIR-AST:LEXICAL-AST> @0x137ccbcf9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  375: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:PROCESS-PARAMETER-GROUPS (CONS T T T T T))> (#<ORDINARY-REQUIRED-PARAMETER-GROUP parameters: (#<CONCRETE-SYNTAX-TREE:SIMPLE-VARIABLE>) @0x137cd2879>) (((NIL))) ((#<CLEAVIR-AST:LEXICAL-AST>)) #<CLEAVIR-CST-TO-AST::BODY> #<LEXICAL-VARIABLE #:TEMP146501 #<CLEAVIR-AST:LEXICAL-AST> @0x137ccbcf9> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  381: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT-CODE (T T T T))> #<CONS-CST raw: (#:STORE146502146503) @0x137ccb339> #<CONS-CST raw: ((CLEAVIR-PRIMOP:MULTIPLE-VALUE-SETQ (#:STORE146502146503) (LAMBDA (STREAMS &OPTIONAL TIMEOUT) (DECLARE (IGNORE STREAMS TIMEOUT)) (CALL-WITH-DEBUGGER-HOOK NIL (LAMBDA NIL (ERROR "~s not implemented. Check if ~s = ~s is supported by the implementation." 'WAIT-FOR-INPUT 'SWANK:*COMMUNICATION-STYLE* SWANK:*COMMUNICATION-STYLE*))))) (LET ((#:STORE146502 #:STORE146502146503)) (FUNCALL #'(SETF GET) #:STORE146502 #:TEMP146500 #:TEMP146501))) @0x137ccb879> #<LEXICAL-VARIABLE #:TEMP146501 #<CLEAVIR-AST:LEXICAL-AST> @0x137ccbcf9> #<CLASP-CLEAVIR::CLASP-64BIT> ORIGIN (#<SOURCE-POS-INFO :fileId 790 :filepos 49721 :lineno 1379 :column 0> . #<SOURCE-POS-INFO :fileId 790 :filepos 50469 :lineno 1394 :column 88>))
# ...
#  400: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT-SPECIAL ((EQL #:|'PROGN|) T T T))> PROGN #<CONS-CST raw: (PROGN (DEFUN REPORT-PARTIAL-TREE (KEY) (UNLESS (EQUAL KEY *VISITOR-KEY*) (SETQ *VISITOR-IDX* 0 *VISITOR-KEY* KEY)) (LET* ((RECENTLY-FINISHED (LOOP WITH I = 0 FOR TRACE IN *UNFINISHED-TRACES* WHILE (< I *TRACES-PER-REPORT*) WHEN (COMPLETED-P TRACE) COLLECT TRACE AND DO (INCF I) (SETQ *UNFINISHED-TRACES* (REMOVE TRACE *UNFINISHED-TRACES*)))) (NEW (LOOP FOR I FROM (LENGTH RECENTLY-FINISHED) BELOW *TRACES-PER-REPORT* WHILE (< *VISITOR-IDX* (LENGTH *TRACES*)) FOR TRACE = (AREF *TRACES* *VISITOR-IDX*) COLLECT TRACE UNLESS (COMPLETED-P TRACE) DO (PUSH TRACE *UNFINISHED-TRACES*) DO (INCF *VISITOR-IDX*)))) (LIST (MAPCAR #'DESCRIBE-TRACE-FOR-EMACS (APPEND RECENTLY-FINISHED NEW)) (- (LENGTH *TRACES*) *VISITOR-IDX*) KEY))) (EVAL-WHEN (:COMPILE-TOPLEVEL :LOAD-TOPLEVEL :EXECUTE) (EXPORT 'REPORT-PARTIAL-TREE (SYMBOL-PACKAGE 'REPORT-PARTIAL-TREE)))) @0x1376fec69> #<CLASP-CLEAVIR:CLASP-GLOBAL-ENVIRONMENT> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  402: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  406: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST::CONVERT-CST (T CLEAVIR-ENVIRONMENT:SPECIAL-OPERATOR-INFO T T))> #<CONS-CST raw: (PROGN (DEFUN REPORT-PARTIAL-TREE (KEY) (UNLESS (EQUAL KEY *VISITOR-KEY*) (SETQ *VISITOR-IDX* 0 *VISITOR-KEY* KEY)) (LET* ((RECENTLY-FINISHED (LOOP WITH I = 0 FOR TRACE IN *UNFINISHED-TRACES* WHILE (< I *TRACES-PER-REPORT*) WHEN (COMPLETED-P TRACE) COLLECT TRACE AND DO (INCF I) (SETQ *UNFINISHED-TRACES* (REMOVE TRACE *UNFINISHED-TRACES*)))) (NEW (LOOP FOR I FROM (LENGTH RECENTLY-FINISHED) BELOW *TRACES-PER-REPORT* WHILE (< *VISITOR-IDX* (LENGTH *TRACES*)) FOR TRACE = (AREF *TRACES* *VISITOR-IDX*) COLLECT TRACE UNLESS (COMPLETED-P TRACE) DO (PUSH TRACE *UNFINISHED-TRACES*) DO (INCF *VISITOR-IDX*)))) (LIST (MAPCAR #'DESCRIBE-TRACE-FOR-EMACS (APPEND RECENTLY-FINISHED NEW)) (- (LENGTH *TRACES*) *VISITOR-IDX*) KEY))) (EVAL-WHEN (:COMPILE-TOPLEVEL :LOAD-TOPLEVEL :EXECUTE) (EXPORT 'REPORT-PARTIAL-TREE (SYMBOL-PACKAGE 'REPORT-PARTIAL-TREE)))) @0x1376fec69> #<CLEAVIR-ENVIRONMENT:SPECIAL-OPERATOR-INFO> #<CLASP-CLEAVIR:CLASP-GLOBAL-ENVIRONMENT> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  410: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (T T T))> #<CONS-CST raw: (PROGN (DEFUN REPORT-PARTIAL-TREE (KEY) (UNLESS (EQUAL KEY *VISITOR-KEY*) (SETQ *VISITOR-IDX* 0 *VISITOR-KEY* KEY)) (LET* ((RECENTLY-FINISHED (LOOP WITH I = 0 FOR TRACE IN *UNFINISHED-TRACES* WHILE (< I *TRACES-PER-REPORT*) WHEN (COMPLETED-P TRACE) COLLECT TRACE AND DO (INCF I) (SETQ *UNFINISHED-TRACES* (REMOVE TRACE *UNFINISHED-TRACES*)))) (NEW (LOOP FOR I FROM (LENGTH RECENTLY-FINISHED) BELOW *TRACES-PER-REPORT* WHILE (< *VISITOR-IDX* (LENGTH *TRACES*)) FOR TRACE = (AREF *TRACES* *VISITOR-IDX*) COLLECT TRACE UNLESS (COMPLETED-P TRACE) DO (PUSH TRACE *UNFINISHED-TRACES*) DO (INCF *VISITOR-IDX*)))) (LIST (MAPCAR #'DESCRIBE-TRACE-FOR-EMACS (APPEND RECENTLY-FINISHED NEW)) (- (LENGTH *TRACES*) *VISITOR-IDX*) KEY))) (EVAL-WHEN (:COMPILE-TOPLEVEL :LOAD-TOPLEVEL :EXECUTE) (EXPORT 'REPORT-PARTIAL-TREE (SYMBOL-PACKAGE 'REPORT-PARTIAL-TREE)))) @0x1376fec69> #<CLASP-CLEAVIR:CLASP-GLOBAL-ENVIRONMENT> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  412: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  413: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (:AROUND) (T T T))> #<FUNCTION REPL> #<CONS-CST raw: (PROGN (DEFUN REPORT-PARTIAL-TREE (KEY) (UNLESS (EQUAL KEY *VISITOR-KEY*) (SETQ *VISITOR-IDX* 0 *VISITOR-KEY* KEY)) (LET* ((RECENTLY-FINISHED (LOOP WITH I = 0 FOR TRACE IN *UNFINISHED-TRACES* WHILE (< I *TRACES-PER-REPORT*) WHEN (COMPLETED-P TRACE) COLLECT TRACE AND DO (INCF I) (SETQ *UNFINISHED-TRACES* (REMOVE TRACE *UNFINISHED-TRACES*)))) (NEW (LOOP FOR I FROM (LENGTH RECENTLY-FINISHED) BELOW *TRACES-PER-REPORT* WHILE (< *VISITOR-IDX* (LENGTH *TRACES*)) FOR TRACE = (AREF *TRACES* *VISITOR-IDX*) COLLECT TRACE UNLESS (COMPLETED-P TRACE) DO (PUSH TRACE *UNFINISHED-TRACES*) DO (INCF *VISITOR-IDX*)))) (LIST (MAPCAR #'DESCRIBE-TRACE-FOR-EMACS (APPEND RECENTLY-FINISHED NEW)) (- (LENGTH *TRACES*) *VISITOR-IDX*) KEY))) (EVAL-WHEN (:COMPILE-TOPLEVEL :LOAD-TOPLEVEL :EXECUTE) (EXPORT 'REPORT-PARTIAL-TREE (SYMBOL-PACKAGE 'REPORT-PARTIAL-TREE)))) @0x1376fec69> #<CLASP-CLEAVIR:CLASP-GLOBAL-ENVIRONMENT> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  415: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<CONS-CST raw: (PROGN (DEFUN REPORT-PARTIAL-TREE (KEY) (UNLESS (EQUAL KEY *VISITOR-KEY*) (SETQ *VISITOR-IDX* 0 *VISITOR-KEY* KEY)) (LET* ((RECENTLY-FINISHED (LOOP WITH I = 0 FOR TRACE IN *UNFINISHED-TRACES* WHILE (< I *TRACES-PER-REPORT*) WHEN (COMPLETED-P TRACE) COLLECT TRACE AND DO (INCF I) (SETQ *UNFINISHED-TRACES* (REMOVE TRACE *UNFINISHED-TRACES*)))) (NEW (LOOP FOR I FROM (LENGTH RECENTLY-FINISHED) BELOW *TRACES-PER-REPORT* WHILE (< *VISITOR-IDX* (LENGTH *TRACES*)) FOR TRACE = (AREF *TRACES* *VISITOR-IDX*) COLLECT TRACE UNLESS (COMPLETED-P TRACE) DO (PUSH TRACE *UNFINISHED-TRACES*) DO (INCF *VISITOR-IDX*)))) (LIST (MAPCAR #'DESCRIBE-TRACE-FOR-EMACS (APPEND RECENTLY-FINISHED NEW)) (- (LENGTH *TRACES*) *VISITOR-IDX*) KEY))) (EVAL-WHEN (:COMPILE-TOPLEVEL :LOAD-TOPLEVEL :EXECUTE) (EXPORT 'REPORT-PARTIAL-TREE (SYMBOL-PACKAGE 'REPORT-PARTIAL-TREE)))) @0x1376fec69> #<CLASP-CLEAVIR:CLASP-GLOBAL-ENVIRONMENT> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  419: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST::CONVERT-CST (T CLEAVIR-ENVIRONMENT:GLOBAL-MACRO-INFO T T))> #<CONS-CST raw: (DEFSLIMEFUN REPORT-PARTIAL-TREE (KEY) (UNLESS (EQUAL KEY *VISITOR-KEY*) (SETQ *VISITOR-IDX* 0 *VISITOR-KEY* KEY)) (LET* ((RECENTLY-FINISHED (LOOP WITH I = 0 FOR TRACE IN *UNFINISHED-TRACES* WHILE (< I *TRACES-PER-REPORT*) WHEN (COMPLETED-P TRACE) COLLECT TRACE AND DO (INCF I) (SETQ *UNFINISHED-TRACES* (REMOVE TRACE *UNFINISHED-TRACES*)))) (NEW (LOOP FOR I FROM (LENGTH RECENTLY-FINISHED) BELOW *TRACES-PER-REPORT* WHILE (< *VISITOR-IDX* (LENGTH *TRACES*)) FOR TRACE = (AREF *TRACES* *VISITOR-IDX*) COLLECT TRACE UNLESS (COMPLETED-P TRACE) DO (PUSH TRACE *UNFINISHED-TRACES*) DO (INCF *VISITOR-IDX*)))) (LIST (MAPCAR #'DESCRIBE-TRACE-FOR-EMACS (APPEND RECENTLY-FINISHED NEW)) (- (LENGTH *TRACES*) *VISITOR-IDX*) KEY))) @0x1376fed59> #<CLEAVIR-ENVIRONMENT:GLOBAL-MACRO-INFO> #<CLASP-CLEAVIR:CLASP-GLOBAL-ENVIRONMENT> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  423: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (T T T))> #<CONS-CST raw: (DEFSLIMEFUN REPORT-PARTIAL-TREE (KEY) (UNLESS (EQUAL KEY *VISITOR-KEY*) (SETQ *VISITOR-IDX* 0 *VISITOR-KEY* KEY)) (LET* ((RECENTLY-FINISHED (LOOP WITH I = 0 FOR TRACE IN *UNFINISHED-TRACES* WHILE (< I *TRACES-PER-REPORT*) WHEN (COMPLETED-P TRACE) COLLECT TRACE AND DO (INCF I) (SETQ *UNFINISHED-TRACES* (REMOVE TRACE *UNFINISHED-TRACES*)))) (NEW (LOOP FOR I FROM (LENGTH RECENTLY-FINISHED) BELOW *TRACES-PER-REPORT* WHILE (< *VISITOR-IDX* (LENGTH *TRACES*)) FOR TRACE = (AREF *TRACES* *VISITOR-IDX*) COLLECT TRACE UNLESS (COMPLETED-P TRACE) DO (PUSH TRACE *UNFINISHED-TRACES*) DO (INCF *VISITOR-IDX*)))) (LIST (MAPCAR #'DESCRIBE-TRACE-FOR-EMACS (APPEND RECENTLY-FINISHED NEW)) (- (LENGTH *TRACES*) *VISITOR-IDX*) KEY))) @0x1376fed59> #<CLASP-CLEAVIR:CLASP-GLOBAL-ENVIRONMENT> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  425: ("_EFFECTIVE-METHOD-FUNCTION.LAMBDA^CLOS^FN^^")
#  426: (#<FUNCTION (METHOD CLEAVIR-CST-TO-AST:CONVERT (:AROUND) (T T T))> #<FUNCTION REPL> #<CONS-CST raw: (DEFSLIMEFUN REPORT-PARTIAL-TREE (KEY) (UNLESS (EQUAL KEY *VISITOR-KEY*) (SETQ *VISITOR-IDX* 0 *VISITOR-KEY* KEY)) (LET* ((RECENTLY-FINISHED (LOOP WITH I = 0 FOR TRACE IN *UNFINISHED-TRACES* WHILE (< I *TRACES-PER-REPORT*) WHEN (COMPLETED-P TRACE) COLLECT TRACE AND DO (INCF I) (SETQ *UNFINISHED-TRACES* (REMOVE TRACE *UNFINISHED-TRACES*)))) (NEW (LOOP FOR I FROM (LENGTH RECENTLY-FINISHED) BELOW *TRACES-PER-REPORT* WHILE (< *VISITOR-IDX* (LENGTH *TRACES*)) FOR TRACE = (AREF *TRACES* *VISITOR-IDX*) COLLECT TRACE UNLESS (COMPLETED-P TRACE) DO (PUSH TRACE *UNFINISHED-TRACES*) DO (INCF *VISITOR-IDX*)))) (LIST (MAPCAR #'DESCRIBE-TRACE-FOR-EMACS (APPEND RECENTLY-FINISHED NEW)) (- (LENGTH *TRACES*) *VISITOR-IDX*) KEY))) @0x1376fed59> #<CLASP-CLEAVIR:CLASP-GLOBAL-ENVIRONMENT> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  428: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<CONS-CST raw: (DEFSLIMEFUN REPORT-PARTIAL-TREE (KEY) (UNLESS (EQUAL KEY *VISITOR-KEY*) (SETQ *VISITOR-IDX* 0 *VISITOR-KEY* KEY)) (LET* ((RECENTLY-FINISHED (LOOP WITH I = 0 FOR TRACE IN *UNFINISHED-TRACES* WHILE (< I *TRACES-PER-REPORT*) WHEN (COMPLETED-P TRACE) COLLECT TRACE AND DO (INCF I) (SETQ *UNFINISHED-TRACES* (REMOVE TRACE *UNFINISHED-TRACES*)))) (NEW (LOOP FOR I FROM (LENGTH RECENTLY-FINISHED) BELOW *TRACES-PER-REPORT* WHILE (< *VISITOR-IDX* (LENGTH *TRACES*)) FOR TRACE = (AREF *TRACES* *VISITOR-IDX*) COLLECT TRACE UNLESS (COMPLETED-P TRACE) DO (PUSH TRACE *UNFINISHED-TRACES*) DO (INCF *VISITOR-IDX*)))) (LIST (MAPCAR #'DESCRIBE-TRACE-FOR-EMACS (APPEND RECENTLY-FINISHED NEW)) (- (LENGTH *TRACES*) *VISITOR-IDX*) KEY))) @0x1376fed59> #<CLASP-CLEAVIR:CLASP-GLOBAL-ENVIRONMENT> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  432: (#<FUNCTION CLEAVIR-CST-TO-AST:CST-TO-AST> #<CONS-CST raw: (DEFSLIMEFUN REPORT-PARTIAL-TREE (KEY) (UNLESS (EQUAL KEY *VISITOR-KEY*) (SETQ *VISITOR-IDX* 0 *VISITOR-KEY* KEY)) (LET* ((RECENTLY-FINISHED (LOOP WITH I = 0 FOR TRACE IN *UNFINISHED-TRACES* WHILE (< I *TRACES-PER-REPORT*) WHEN (COMPLETED-P TRACE) COLLECT TRACE AND DO (INCF I) (SETQ *UNFINISHED-TRACES* (REMOVE TRACE *UNFINISHED-TRACES*)))) (NEW (LOOP FOR I FROM (LENGTH RECENTLY-FINISHED) BELOW *TRACES-PER-REPORT* WHILE (< *VISITOR-IDX* (LENGTH *TRACES*)) FOR TRACE = (AREF *TRACES* *VISITOR-IDX*) COLLECT TRACE UNLESS (COMPLETED-P TRACE) DO (PUSH TRACE *UNFINISHED-TRACES*) DO (INCF *VISITOR-IDX*)))) (LIST (MAPCAR #'DESCRIBE-TRACE-FOR-EMACS (APPEND RECENTLY-FINISHED NEW)) (- (LENGTH *TRACES*) *VISITOR-IDX*) KEY))) @0x1376fed59> #<CLASP-CLEAVIR:CLASP-GLOBAL-ENVIRONMENT> #<CLASP-CLEAVIR::CLASP-64BIT>)
#  433: (#<FUNCTION CLASP-CLEAVIR::CST->AST> #<CONS-CST raw: (DEFSLIMEFUN REPORT-PARTIAL-TREE (KEY) (UNLESS (EQUAL KEY *VISITOR-KEY*) (SETQ *VISITOR-IDX* 0 *VISITOR-KEY* KEY)) (LET* ((RECENTLY-FINISHED (LOOP WITH I = 0 FOR TRACE IN *UNFINISHED-TRACES* WHILE (< I *TRACES-PER-REPORT*) WHEN (COMPLETED-P TRACE) COLLECT TRACE AND DO (INCF I) (SETQ *UNFINISHED-TRACES* (REMOVE TRACE *UNFINISHED-TRACES*)))) (NEW (LOOP FOR I FROM (LENGTH RECENTLY-FINISHED) BELOW *TRACES-PER-REPORT* WHILE (< *VISITOR-IDX* (LENGTH *TRACES*)) FOR TRACE = (AREF *TRACES* *VISITOR-IDX*) COLLECT TRACE UNLESS (COMPLETED-P TRACE) DO (PUSH TRACE *UNFINISHED-TRACES*) DO (INCF *VISITOR-IDX*)))) (LIST (MAPCAR #'DESCRIBE-TRACE-FOR-EMACS (APPEND RECENTLY-FINISHED NEW)) (- (LENGTH *TRACES*) *VISITOR-IDX*) KEY))) @0x1376fed59>)
#  434: (#<FUNCTION COMPILER::CCLASP-LOOP2> /Users/meister/Dropbox/emacs.d/slime/contrib/swank-trace-dialog.lisp #<IOSTREAM-STREAM #P"/Users/meister/Dropbox/emacs.d/slime/contrib/swank-trace-dialog.lisp"> NIL DRY-RUN NIL OPTIMIZE T OPTIMIZE-LEVEL 3 OUTPUT-PATH /Users/meister/Dropbox/emacs.d/slime/fasl/contrib/swank-trace-dialog.fasp INTERMEDIATE-OUTPUT-TYPE IN-MEMORY-OBJECT AST-ONLY NIL WRITE-BITCODE NIL)
#  435: (#<FUNCTION COMPILER::COMPILE-FILE-TO-RESULT> /Users/meister/Dropbox/emacs.d/slime/contrib/swank-trace-dialog.lisp OUTPUT-TYPE FASP OUTPUT-PATH /Users/meister/Dropbox/emacs.d/slime/fasl/contrib/swank-trace-dialog.fasp COMPILE-FILE-HOOK CCLASP-LOOP-READ-AND-COMPILE-FILE-FORMS ENVIRONMENT NIL OPTIMIZE T OPTIMIZE-LEVEL 3 AST-ONLY NIL DRY-RUN NIL WRITE-BITCODE NIL)
#  436: (#<FUNCTION (LAMBDA NIL)>)
#  437: (#<FUNCTION COMPILER::CALL-WITH-COMPILATION-RESULTS> #<FUNCTION (LAMBDA NIL)>)
#  438: (#<FUNCTION (LAMBDA NIL)>)
#  439: (#<FUNCTION COMPILER::DO-COMPILER-TIMER> #<FUNCTION (LAMBDA NIL)>)
#  440: (#<FUNCTION COMPILER::DO-COMPILER-TIMER> #<FUNCTION (LAMBDA NIL)> MESSAGE Compile-file-parallel REPORT-LINK-TIME T VERBOSE T)
#  441: (#<FUNCTION (LAMBDA NIL)>)
#  442: (#<FUNCTION COMPILER::DO-COMPILATION-UNIT> #<FUNCTION (LAMBDA NIL)>)
#  443: (#<FUNCTION COMPILER:COMPILE-FILE-PARALLEL> /Users/meister/Dropbox/emacs.d/slime/contrib/swank-trace-dialog.lisp OUTPUT-FILE /Users/meister/Dropbox/emacs.d/slime/fasl/contrib/swank-trace-dialog.fasp PRINT NIL VERBOSE T)
#  445: (#<FUNCTION (FLET COMPILER::DO-COMPILE-FILE)>)
#  446: (#<FUNCTION (LAMBDA NIL)>)
#  447: (#<FUNCTION CORE::DO-TIME> #<FUNCTION (LAMBDA NIL)>)
#  448: (#<FUNCTION COMPILE-FILE> /Users/meister/Dropbox/emacs.d/slime/contrib/swank-trace-dialog.lisp OUTPUT-FILE /Users/meister/Dropbox/emacs.d/slime/fasl/contrib/swank-trace-dialog.fasp PRINT NIL VERBOSE T)
#  449: (#<FUNCTION SWANK-LOADER::COMPILE-FILES> (/Users/meister/Dropbox/emacs.d/slime/contrib/swank-util.lisp /Users/meister/Dropbox/emacs.d/slime/contrib/swank-repl.lisp /Users/meister/Dropbox/emacs.d/slime/contrib/swank-c-p-c.lisp /Users/meister/Dropbox/emacs.d/slime/contrib/swank-arglists.lisp /Users/meister/Dropbox/emacs.d/slime/contrib/swank-fuzzy.lisp /Users/meister/Dropbox/emacs.d/slime/contrib/swank-fancy-inspector.lisp /Users/meister/Dropbox/emacs.d/slime/contrib/swank-presentations.lisp /Users/meister/Dropbox/emacs.d/slime/contrib/swank-presentation-streams.lisp /Users/meister/Dropbox/emacs.d/slime/contrib/swank-asdf.lisp /Users/meister/Dropbox/emacs.d/slime/contrib/swank-package-fu.lisp /Users/meister/Dropbox/emacs.d/slime/contrib/swank-hyperdoc.lisp /Users/meister/Dropbox/emacs.d/slime/contrib/swank-mrepl.lisp /Users/meister/Dropbox/emacs.d/slime/contrib/swank-trace-dialog.lisp /Users/meister/Dropbox/emacs.d/slime/contrib/swank-macrostep.lisp /Users/meister/Dropbox/emacs.d/slime/contrib/swank-quicklisp.lisp) /Users/meister/Dropbox/emacs.d/slime/fasl/contrib/ NIL NIL)
#  450: (#<FUNCTION SWANK-LOADER::COMPILE-CONTRIBS>)
#  452: (#<FUNCTION SWANK::RUN-HOOK> (COMPILE-CONTRIBS INIT-LOG-OUTPUT))
#  453: (#<FUNCTION SWANK::INIT>)
#  454: (#<FUNCTION SWANK-LOADER::SETUP>)
#  455: (#<FUNCTION SWANK-LOADER:INIT> DELETE NIL RELOAD NIL LOAD-CONTRIBS NIL)
#  456: (#<FUNCTION CANDO-USER::START-SWANK-SERVER> 4006)
#  457: (#<FUNCTION CANDO-USER:START-SWANK> 4006)
#  459: (#<FUNCTION CLASP-CLEAVIR::SIMPLE-EVAL> (START-SWANK 4006) NIL #<STANDARD-GENERIC-FUNCTION CLASP-CLEAVIR::CCLASP-EVAL-WITH-ENV>)
#  460: (#<FUNCTION CLASP-CLEAVIR::CCLASP-EVAL> (START-SWANK 4006) NIL)
#  462: (#<FUNCTION COMMON-LISP-JUPYTER::MY-EVAL> (START-SWANK 4006))
#  463: (#<FUNCTION (METHOD JUPYTER:EVALUATE-CODE (COMMON-LISP-JUPYTER:KERNEL T))> #<CANDO-JUPYTER:KERNEL> (start-swank 4006))
#  464: (#<FUNCTION (METHOD JUPYTER:EVALUATE-CODE (CANDO-JUPYTER:KERNEL T))> #<FUNCTION (METHOD EVALUATE-CODE (KERNEL T))> #<CANDO-JUPYTER:KERNEL> (start-swank 4006))
#  466: (#<FUNCTION CLOS::EMF-FROM-CONTF.LAMBDA> #<CANDO-JUPYTER:KERNEL> (start-swank 4006))
#  470: (#<FUNCTION JUPYTER::HANDLE-EXECUTE-REQUEST> #<CANDO-JUPYTER:KERNEL> #<JUPYTER::MESSAGE>)
#  471: (#<FUNCTION JUPYTER::HANDLE-MESSAGE> #<CANDO-JUPYTER:KERNEL> #<JUPYTER::MESSAGE>)
#  472: (#<FUNCTION JUPYTER:RUN-KERNEL> KERNEL /Users/meister/Library/Jupyter/runtime/kernel-e7c28fca-3c6f-4978-b38b-1fb7b15aa75f.json)
#  474: (#<FUNCTION CLASP-CLEAVIR::SIMPLE-EVAL> (RUN-KERNEL 'KERNEL /Users/meister/Library/Jupyter/runtime/kernel-e7c28fca-3c6f-4978-b38b-1fb7b15aa75f.json) NIL #<STANDARD-GENERIC-FUNCTION CLASP-CLEAVIR::CCLASP-EVAL-WITH-ENV>)
#  475: (#<FUNCTION CLASP-CLEAVIR::CCLASP-EVAL> (RUN-KERNEL 'KERNEL /Users/meister/Library/Jupyter/runtime/kernel-e7c28fca-3c6f-4978-b38b-1fb7b15aa75f.json) NIL)
#  477: (#<FUNCTION (LAMBDA (CORE::ENTRY))> (EVAL . (jupyter:run-kernel 'cando-jupyter:kernel #"/Users/meister/Library/Jupyter/runtime/kernel-e7c28fca-3c6f-4978-b38b-1fb7b15aa75f.json")))
#  480: (#<FUNCTION MAPCAR> #<FUNCTION (LAMBDA (ENTRY))> ((LOAD . source-dir:extensions;cando;src;lisp;start-cando.lisp) (EVAL . (in-package :cando-user)) (EVAL . (ql:quickload :cando-jupyter)) (EVAL . (jupyter:run-kernel 'cando-jupyter:kernel #"/Users/meister/Library/Jupyter/runtime/kernel-e7c28fca-3c6f-4978-b38b-1fb7b15aa75f.json"))))
#  481: (#<FUNCTION CORE:PROCESS-COMMAND-LINE-LOAD-EVAL-SEQUENCE>)
#  486: ("_RUN-ALL/Users/meister/Development/cando/src/lisp/kernel/lsp/epilogue-cclasp.lisp")
